# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataPath='/content/data.csv'

df=pd.read_csv(dataPath)
print(df.shape)
# Out:
# (41188, 21)

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# # preprocessing

# %%
df.rename(columns={'default':'has-credit', 'housing':'housing-loan','loan':'personal-loan','nr.employed:':'no-employees','y':'target'}, inplace=True)
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'has-credit', 'housing-loan',
#        'personal-loan', 'contact', 'month', 'day_of_week', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
#        'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    age        job  marital    education has-credit housing-loan personal-loan  \
# 0   56  housemaid  married     basic.4y         no           no            no
# 1   57   services  married  high.school    unknown           no            no
# 2   37   services  married  high.school         no          yes            no
# 3   40     admin.  married     basic.6y         no           no            no
# 4   56   services  married  high.school         no           no           yes
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# 1  telephone   may         mon  ...         1    999         0  nonexistent
# 2  telephone   may         mon  ...         1    999         0  nonexistent
# 3  telephone   may         mon  ...         1    999         0  nonexistent
# 4  telephone   may         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  target
# 0          1.1          93.994          -36.4      4.857       5191.0      no
# 1          1.1          93.994          -36.4      4.857       5191.0      no
# 2          1.1          93.994          -36.4      4.857       5191.0      no
# 3          1.1          93.994          -36.4      4.857       5191.0      no
# 4          1.1          93.994          -36.4      4.857       5191.0      no
#
# [5 rows x 21 columns]

# %%
df.describe(include="all")
# Out:
#                 age     job  marital          education has-credit  \
# count   41188.00000   41188    41188              41188      41188
# unique          NaN      12        4                  8          3
# top             NaN  admin.  married  university.degree         no
# freq            NaN   10422    24928              12168      32588
# mean       40.02406     NaN      NaN                NaN        NaN
# std        10.42125     NaN      NaN                NaN        NaN
# min        17.00000     NaN      NaN                NaN        NaN
# 25%        32.00000     NaN      NaN                NaN        NaN
# 50%        38.00000     NaN      NaN                NaN        NaN
# 75%        47.00000     NaN      NaN                NaN        NaN
# max        98.00000     NaN      NaN                NaN        NaN
#
#        housing-loan personal-loan   contact  month day_of_week  ...  \
# count         41188         41188     41188  41188       41188  ...
# unique            3             3         2     10           5  ...
# top             yes            no  cellular    may         thu  ...
# freq          21576         33950     26144  13769        8623  ...
# mean            NaN           NaN       NaN    NaN         NaN  ...
# std             NaN           NaN       NaN    NaN         NaN  ...
# min             NaN           NaN       NaN    NaN         NaN  ...
# 25%             NaN           NaN       NaN    NaN         NaN  ...
# 50%             NaN           NaN       NaN    NaN         NaN  ...
# 75%             NaN           NaN       NaN    NaN         NaN  ...
# max             NaN           NaN       NaN    NaN         NaN  ...
#
#             campaign         pdays      previous     poutcome  emp.var.rate  \
# count   41188.000000  41188.000000  41188.000000        41188  41188.000000
# unique           NaN           NaN           NaN            3           NaN
# top              NaN           NaN           NaN  nonexistent           NaN
# freq             NaN           NaN           NaN        35563           NaN
# mean        2.567593    962.475454      0.172963          NaN      0.081886
# std         2.770014    186.910907      0.494901          NaN      1.570960
# min         1.000000      0.000000      0.000000          NaN     -3.400000
# 25%         1.000000    999.000000      0.000000          NaN     -1.800000
# 50%         2.000000    999.000000      0.000000          NaN      1.100000
# 75%         3.000000    999.000000      0.000000          NaN      1.400000
# max        56.000000    999.000000      7.000000          NaN      1.400000
#
#         cons.price.idx  cons.conf.idx     euribor3m   nr.employed  target
# count     41188.000000   41188.000000  41188.000000  41188.000000   41188
# unique             NaN            NaN           NaN           NaN       2
# top                NaN            NaN           NaN           NaN      no
# freq               NaN            NaN           NaN           NaN   36548
# mean         93.575664     -40.502600      3.621291   5167.035911     NaN
# std           0.578840       4.628198      1.734447     72.251528     NaN
# min          92.201000     -50.800000      0.634000   4963.600000     NaN
# 25%          93.075000     -42.700000      1.344000   5099.100000     NaN
# 50%          93.749000     -41.800000      4.857000   5191.000000     NaN
# 75%          93.994000     -36.400000      4.961000   5228.100000     NaN
# max          94.767000     -26.900000      5.045000   5228.100000     NaN
#
# [11 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   has-credit      41188 non-null  object
#  5   housing-loan    41188 non-null  object
#  6   personal-loan   41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  target          41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %%
df.nunique()
# Out:
# age                 78
# job                 12
# marital              4
# education            8
# has-credit           3
# housing-loan         3
# personal-loan        3
# contact              2
# month               10
# day_of_week          5
# duration          1544
# campaign            42
# pdays               27
# previous             8
# poutcome             3
# emp.var.rate        10
# cons.price.idx      26
# cons.conf.idx       26
# euribor3m          316
# nr.employed         11
# target               2
# dtype: int64

# %% [markdown]
# # visualization

# %%
count_col = []
hist_col = []
for column in df.columns:
    unique_value = df[column].nunique()
    if unique_value <= 20:
        count_col.append(column)
    else:
        hist_col.append(column)

plt.figure(figsize=(20,40))
plot_num = 1
for col in count_col:
    plt.subplot(10,2,plot_num)
    sns.countplot(data=df, x=col,hue='target')
    plot_num += 1
    plt.tight_layout()

# %% [markdown]
# # data balancing

# %%
df['target'].value_counts()
# Out:
# target
# no     36548
# yes     4640
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

df_major=df[(df['target']=='no')]
df_min=df[(df['target']=='yes')]

df_min_upsampled=resample(df_min,
                          replace=True,
                          n_samples=36548,
                          random_state=42)
df_upsampled=pd.concat([df_min_upsampled,df_major])

# %%
df_upsampled['target'].value_counts()
# Out:
# target
# yes    36548
# no     36548
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.countplot(x=df['target'],data=df, ax=ax[0],hue='target')
sns.countplot(x=df_upsampled['target'],data=df_upsampled, ax=ax[1],hue='target')
ax[0].set_title("Before Upsamplig")
ax[1].set_title("After Upsampling")

# set spacing
fig.tight_layout()
plt.show()

# %% [markdown]
# #  Convert categorical data to numerical data

# %%
df_upsampled['target'] = df_upsampled['target'].replace({'no': 0, 'yes': 1})

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for column in df_upsampled.columns:
    if df_upsampled[column].dtype == 'object':
        df_upsampled[column] = label_encoder.fit_transform(df_upsampled[column].astype(str))
df_upsampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73096 entries, 19199 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             73096 non-null  int64
#  1   job             73096 non-null  int64
#  2   marital         73096 non-null  int64
#  3   education       73096 non-null  int64
#  4   has-credit      73096 non-null  int64
#  5   housing-loan    73096 non-null  int64
#  6   personal-loan   73096 non-null  int64
#  7   contact         73096 non-null  int64
#  8   month           73096 non-null  int64
#  9   day_of_week     73096 non-null  int64
#  10  duration        73096 non-null  int64
#  11  campaign        73096 non-null  int64
#  12  pdays           73096 non-null  int64
#  13  previous        73096 non-null  int64
#  14  poutcome        73096 non-null  int64
#  15  emp.var.rate    73096 non-null  float64
#  16  cons.price.idx  73096 non-null  float64
#  17  cons.conf.idx   73096 non-null  float64
#  18  euribor3m       73096 non-null  float64
#  19  nr.employed     73096 non-null  float64
#  20  target          73096 non-null  int64
# dtypes: float64(5), int64(16)
# memory usage: 12.3 MB

# %% [markdown]
# # visualization of numerical

# %%
numeric_columns={0:'age',1:'duration',2:'campaign',3:'pdays',4:'previous',5:'emp.var.rate',6:'cons.price.idx',7:'cons.conf.idx',8:'euribor3m',9:'nr.employed'}

plt.figure(figsize=(20,40))
plot_num = 1
for col in numeric_columns:
    plt.subplot(5,2,plot_num)
    sns.regplot(x=df_upsampled[numeric_columns[col]],y="target",data=df_upsampled)
    plot_num += 1
    plt.tight_layout()

# %%
df_upsampled.dtypes
# Out:
# age                 int64
# job                 int64
# marital             int64
# education           int64
# has-credit          int64
# housing-loan        int64
# personal-loan       int64
# contact             int64
# month               int64
# day_of_week         int64
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome            int64
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# target              int64
# dtype: object

# %% [markdown]
# # visualization of categorical

# %%
catagorial_columns={0:"job",1:"marital",2:"education",3:"has-credit",4:"housing-loan",5:"personal-loan",6:"contact",7:"month",8:"day_of_week",9:"poutcome"}

plt.figure(figsize=(10,20))
plot_num = 1
for col in catagorial_columns:
    plt.subplot(5,2,plot_num)
    sns.boxplot(x=df_upsampled[catagorial_columns[col]],y="target",data=df_upsampled)
    plot_num += 1
    plt.tight_layout()

# %% [markdown]
# # standarization

# %%
from sklearn.preprocessing import  StandardScaler
sc=StandardScaler()
scaled_standard =sc.fit_transform(df_upsampled)
scaled_standard_df = pd.DataFrame(scaled_standard, columns=df_upsampled.columns)
print("\nStandardized Data:")
print(scaled_standard_df)
# Out:
# Standardized Data:
#             age       job   marital  education  has-credit  housing-loan  \
# 0     -0.528039  1.429198  1.277588   0.982217   -0.432445      0.930536
# 1      1.379098 -0.231020 -0.333831  -1.828375   -0.432445     -1.100563
# 2     -0.362201 -1.061129  1.277588   0.982217   -0.432445      0.930536
# 3     -1.108472 -1.061129  1.277588   0.513785   -0.432445     -1.100563
# 4      1.627855  0.322386 -0.333831  -0.423079   -0.432445     -1.100563
# ...         ...       ...       ...        ...         ...           ...
# 73091 -0.362201 -1.061129 -0.333831   0.982217   -0.432445     -1.100563
# 73092 -0.942634  1.705901  1.277588  -1.828375   -0.432445      0.930536
# 73093  0.466989 -0.784426 -0.333831   0.513785   -0.432445     -1.100563
# 73094  1.296179  0.322386 -0.333831   0.982217   -0.432445      0.930536
# 73095  2.788721  0.322386 -0.333831   0.513785   -0.432445      0.930536
#
#        personal-loan   contact     month  day_of_week  ...  campaign  \
# 0           2.341430 -0.621877 -1.278346     1.413992  ...  0.278176
# 1          -0.446492 -0.621877 -1.677479     1.413992  ... -0.143533
# 2          -0.446492 -0.621877  1.914723    -1.459215  ... -0.143533
# 3          -0.446492 -0.621877 -0.480079     0.695690  ... -0.143533
# 4          -0.446492 -0.621877  1.914723     1.413992  ... -0.565243
# ...              ...       ...       ...          ...  ...       ...
# 73091      -0.446492 -0.621877  1.116456    -1.459215  ... -0.143533
# 73092      -0.446492 -0.621877  1.116456    -1.459215  ... -0.565243
# 73093      -0.446492 -0.621877  1.116456    -1.459215  ... -0.565243
# 73094      -0.446492 -0.621877  1.116456    -1.459215  ... -0.143533
# 73095      -0.446492 -0.621877  1.116456    -1.459215  ...  0.278176
#
#           pdays  previous  poutcome  emp.var.rate  cons.price.idx  \
# 0      0.355365 -0.446491  0.022054      1.100686       -0.047166
# 1     -2.813800  0.981936  2.168650     -0.753377        0.434460
# 2      0.355365 -0.446491  0.022054     -1.680409       -1.728912
# 3      0.355365 -0.446491  0.022054      1.100686        0.701329
# 4     -2.813800  0.981936  2.168650     -0.347801        1.145057
# ...         ...       ...       ...           ...             ...
# 73091  0.355365 -0.446491  0.022054     -0.347801        2.041988
# 73092 -2.804225  0.981936  2.168650     -0.347801        2.041988
# 73093  0.355365 -0.446491  0.022054     -0.347801        2.041988
# 73094  0.355365 -0.446491  0.022054     -0.347801        2.041988
# 73095  0.355365  0.981936 -2.124541     -0.347801        2.041988
#
#        cons.conf.idx  euribor3m  nr.employed  target
# 0           0.756783   1.060838     1.066265     1.0
# 1           1.035775  -1.227029    -1.461979     1.0
# 2           1.928551  -1.157732    -1.360572     1.0
# 3          -0.470784   1.058193     1.066265     1.0
# 4           0.496390  -1.103247    -1.981686     1.0
# ...              ...        ...          ...     ...
# 73091      -1.977344  -1.022841    -1.981686    -1.0
# 73092      -1.977344  -1.022841    -1.981686    -1.0
# 73093      -1.977344  -1.022841    -1.981686    -1.0
# 73094      -1.977344  -1.022841    -1.981686    -1.0
# 73095      -1.977344  -1.022841    -1.981686    -1.0
#
# [73096 rows x 21 columns]

# %%
df_upsampled.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# has-credit        0
# housing-loan      0
# personal-loan     0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# target            0
# dtype: int64

# %%
df_upsampled.nunique()
# Out:
# age                 78
# job                 12
# marital              4
# education            8
# has-credit           3
# housing-loan         3
# personal-loan        3
# contact              2
# month               10
# day_of_week          5
# duration          1544
# campaign            42
# pdays               27
# previous             8
# poutcome             3
# emp.var.rate        10
# cons.price.idx      26
# cons.conf.idx       26
# euribor3m          316
# nr.employed         11
# target               2
# dtype: int64

# %% [markdown]
# # correlation

# %%
#strong negative
df_upsampled[["nr.employed", "target"]].corr()           #pdays  emp.var.rate  cons.price.idx  euribor3m
# Out:
#              nr.employed    target
# nr.employed     1.000000 -0.467814
# target         -0.467814  1.000000

# %%
sns.regplot(x="nr.employed", y="target", data=df_upsampled)
#age', 'job', 'marital', 'education', 'has-credit', 'housing-loan',
#        'personal-loan', 'contact', 'month', 'day_of_week', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed',
#        'target'
# Out:
# <Axes: xlabel='nr.employed', ylabel='target'>

# %%
#strong positive
df_upsampled[["duration", "target"]].corr()     #poutcome   previous
# Out:
#           duration    target
# duration  1.000000  0.458411
# target    0.458411  1.000000

# %%
sns.regplot(x="duration", y="target", data=df_upsampled)
# Out:
# <Axes: xlabel='duration', ylabel='target'>

# %%
sns.regplot(x="previous", y="target", data=df_upsampled)
# Out:
# <Axes: xlabel='previous', ylabel='target'>

# %%
#weak relation
df_upsampled[["education", "target"]].corr()   #day_of_week
# Out:
#            education    target
# education   1.000000  0.093685
# target      0.093685  1.000000

# %%
sns.regplot(x="education", y="target", data=df_upsampled)
# Out:
# <Axes: xlabel='education', ylabel='target'>

# %%
df_upsampled.corr()
# Out:
#                      age       job   marital  education  has-credit  \
# age             1.000000 -0.010290 -0.432932  -0.158023    0.120210
# job            -0.010290  1.000000  0.047330   0.090507   -0.033739
# marital        -0.432932  0.047330  1.000000   0.128073   -0.087512
# education      -0.158023  0.090507  0.128073   1.000000   -0.185068
# has-credit      0.120210 -0.033739 -0.087512  -0.185068    1.000000
# housing-loan    0.002771  0.013944  0.012388   0.019592   -0.019878
# personal-loan  -0.001028  0.002936  0.000111   0.003375   -0.000604
# contact        -0.008776 -0.035466 -0.060961  -0.102066    0.168453
# month          -0.025242 -0.013718 -0.004109  -0.060326   -0.011950
# day_of_week     0.002254 -0.006162 -0.001626  -0.017935   -0.018351
# duration       -0.025165 -0.009084  0.003476  -0.024563    0.008813
# campaign       -0.007499 -0.011409 -0.018799  -0.003619    0.054659
# pdays          -0.065998 -0.039599 -0.035311  -0.071044    0.126069
# previous        0.065394  0.045406  0.032645   0.070926   -0.133895
# poutcome        0.034389  0.008540  0.014224   0.035702   -0.031229
# emp.var.rate   -0.052795 -0.032741 -0.101769  -0.090585    0.273166
# cons.price.idx -0.021556 -0.014768 -0.063188  -0.073044    0.174749
# cons.conf.idx   0.144831  0.050454 -0.022441   0.062337   -0.005718
# euribor3m      -0.048196 -0.036449 -0.106265  -0.088203    0.272136
# nr.employed    -0.077311 -0.052695 -0.094566  -0.096768    0.264043
# target          0.037890  0.039429  0.071581   0.093685   -0.180079
#
#                 housing-loan  personal-loan   contact     month  day_of_week  \
# age                 0.002771      -0.001028 -0.008776 -0.025242     0.002254
# job                 0.013944       0.002936 -0.035466 -0.013718    -0.006162
# marital             0.012388       0.000111 -0.060961 -0.004109    -0.001626
# education           0.019592       0.003375 -0.102066 -0.060326    -0.017935
# has-credit         -0.019878      -0.000604  0.168453 -0.011950    -0.018351
# housing-loan        1.000000       0.042995 -0.071828 -0.022381    -0.000665
# personal-loan       0.042995       1.000000 -0.004100 -0.004409    -0.008685
# contact            -0.071828      -0.004100  1.000000  0.203098    -0.011410
# month              -0.022381      -0.004409  0.203098  1.000000     0.010611
# day_of_week        -0.000665      -0.008685 -0.011410  0.010611     1.000000
# duration           -0.013103       0.008487 -0.016390 -0.017877     0.013313
# campaign           -0.007082       0.006917  0.108255 -0.061831    -0.050061
# pdays              -0.015256      -0.005018  0.161520 -0.080944    -0.016651
# previous            0.016598      -0.002542 -0.210511  0.106205     0.016237
# poutcome            0.004171       0.000841  0.017448 -0.002247     0.017522
# emp.var.rate       -0.053739       0.008969  0.418969 -0.137714     0.017771
# cons.price.idx     -0.063721       0.005890  0.488738  0.021009     0.012642
# cons.conf.idx      -0.027488      -0.014784  0.143836  0.068729     0.021560
# euribor3m          -0.053881       0.006490  0.435604 -0.094493     0.016545
# nr.employed        -0.040350       0.009108  0.329998 -0.205854     0.002856
# target              0.016297      -0.011690 -0.247988 -0.013203     0.025009
#
#                 ...  campaign     pdays  previous  poutcome  emp.var.rate  \
# age             ... -0.007499 -0.065998  0.065394  0.034389     -0.052795
# job             ... -0.011409 -0.039599  0.045406  0.008540     -0.032741
# marital         ... -0.018799 -0.035311  0.032645  0.014224     -0.101769
# education       ... -0.003619 -0.071044  0.070926  0.035702     -0.090585
# has-credit      ...  0.054659  0.126069 -0.133895 -0.031229      0.273166
# housing-loan    ... -0.007082 -0.015256  0.016598  0.004171     -0.053739
# personal-loan   ...  0.006917 -0.005018 -0.002542  0.000841      0.008969
# contact         ...  0.108255  0.161520 -0.210511  0.017448      0.418969
# month           ... -0.061831 -0.080944  0.106205 -0.002247     -0.137714
# day_of_week     ... -0.050061 -0.016651  0.016237  0.017522      0.017771
# duration        ... -0.025912  0.028194 -0.043182  0.002899      0.067301
# campaign        ...  1.000000  0.093810 -0.103734 -0.015659      0.196163
# pdays           ...  0.093810  1.000000 -0.708704 -0.652785      0.332964
# previous        ... -0.103734 -0.708704  1.000000  0.091730     -0.380971
# poutcome        ... -0.015659 -0.652785  0.091730  1.000000     -0.007813
# emp.var.rate    ...  0.196163  0.332964 -0.380971 -0.007813      1.000000
# cons.price.idx  ...  0.135453  0.034788 -0.059302  0.119411      0.724364
# cons.conf.idx   ... -0.032134 -0.156230  0.079928  0.125877     -0.069664
# euribor3m       ...  0.184992  0.387262 -0.448595 -0.037797      0.959068
# nr.employed     ...  0.186564  0.475036 -0.524048 -0.115075      0.870727
# target          ... -0.123445 -0.307856  0.257405  0.164014     -0.433730
#
#                 cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# age                  -0.021556       0.144831  -0.048196    -0.077311
# job                  -0.014768       0.050454  -0.036449    -0.052695
# marital              -0.063188      -0.022441  -0.106265    -0.094566
# education            -0.073044       0.062337  -0.088203    -0.096768
# has-credit            0.174749      -0.005718   0.272136     0.264043
# housing-loan         -0.063721      -0.027488  -0.053881    -0.040350
# personal-loan         0.005890      -0.014784   0.006490     0.009108
# contact               0.488738       0.143836   0.435604     0.329998
# month                 0.021009       0.068729  -0.094493    -0.205854
# day_of_week           0.012642       0.021560   0.016545     0.002856
# duration              0.054760      -0.055885   0.053673     0.055967
# campaign              0.135453      -0.032134   0.184992     0.186564
# pdays                 0.034788      -0.156230   0.387262     0.475036
# previous             -0.059302       0.079928  -0.448595    -0.524048
# poutcome              0.119411       0.125877  -0.037797    -0.115075
# emp.var.rate          0.724364      -0.069664   0.959068     0.870727
# cons.price.idx        1.000000      -0.164214   0.577660     0.359325
# cons.conf.idx        -0.164214       1.000000   0.037529    -0.094772
# euribor3m             0.577660       0.037529   1.000000     0.941483
# nr.employed           0.359325      -0.094772   0.941483     1.000000
# target               -0.205106       0.078911  -0.449589    -0.467814
#
#                   target
# age             0.037890
# job             0.039429
# marital         0.071581
# education       0.093685
# has-credit     -0.180079
# housing-loan    0.016297
# personal-loan  -0.011690
# contact        -0.247988
# month          -0.013203
# day_of_week     0.025009
# duration        0.458411
# campaign       -0.123445
# pdays          -0.307856
# previous        0.257405
# poutcome        0.164014
# emp.var.rate   -0.433730
# cons.price.idx -0.205106
# cons.conf.idx   0.078911
# euribor3m      -0.449589
# nr.employed    -0.467814
# target          1.000000
#
# [21 rows x 21 columns]

# %%
plt.subplots(figsize=(30,30))
sns.heatmap(df_upsampled.corr(), annot=True, cmap="RdYlGn")
plt.show()

# %% [markdown]
# # Grouping

# %%
df_group_one = df_upsampled[['has-credit','education','previous','nr.employed','target']]

# %%
df_group_one = df_group_one.groupby(['has-credit'],as_index=False).mean()
df_group_one
# Out:
#    has-credit  education  previous  nr.employed    target
# 0           0   4.074151  0.353135  5125.659413  0.538935
# 1           1   2.988885  0.095693  5188.540952  0.291942
# 2           2   4.333333  0.333333  5217.333333  0.000000

# %%
grouped_pivot = pd.pivot_table(df_group_one, index='has-credit', columns='previous', values='nr.employed')
grouped_pivot
# Out:
# previous       0.095693     0.333333     0.353135
# has-credit
# 0                   NaN          NaN  5125.659413
# 1           5188.540952          NaN          NaN
# 2                   NaN  5217.333333          NaN

# %%
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0
grouped_pivot
# Out:
# previous       0.095693     0.333333     0.353135
# has-credit
# 0              0.000000     0.000000  5125.659413
# 1           5188.540952     0.000000     0.000000
# 2              0.000000  5217.333333     0.000000

# %%
plt.pcolor(grouped_pivot)
plt.colorbar()
plt.show()

# %% [markdown]
# # Building models

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(df_upsampled.drop('target',axis=1),
                                                    df_upsampled['target'], test_size=0.40,
                                                    random_state=None)

# %%
print("number of test samples :", X_test.shape[0])
print("number of training samples:",X_train.shape[0])
# Out:
# number of test samples : 29239
# number of training samples: 43857

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logist_model = LogisticRegression()

# %%
logist_model.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression()

# %%
LG_pred = logist_model.predict(X_test)

LG_accuracy = accuracy_score(y_test, LG_pred)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,LG_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85     14633
#            1       0.85      0.85      0.85     14606
#
#     accuracy                           0.85     29239
#    macro avg       0.85      0.85      0.85     29239
# weighted avg       0.85      0.85      0.85     29239

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
log_matrix = confusion_matrix(y_test,LG_pred)
log_display = ConfusionMatrixDisplay(confusion_matrix = log_matrix, display_labels = ['NO','YES'])
log_display.plot()
plt.title("Confusion Matrix of Logistic Regression")
plt.show()

# %% [markdown]
# # Gridsearch fine_tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = [{'penalty':['l1','l2','15']},
              {'C':[1, 10, 100, 1000]}]

grid = GridSearchCV(LogisticRegression(), param, refit = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_upsampled.drop('target',axis=1),
                                                    df_upsampled['target'], test_size=0.30,
                                                    random_state=None)
grid.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
#
#
# 10 fits failed out of a total of 35.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'none' (deprecated), 'elasticnet', 'l1', 'l2'} or None. Got '15' instead.
#
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning:
#
# One or more of the test scores are non-finite: [       nan 0.85295203        nan 0.85295203 0.85299108 0.85224846
#  0.85402693]
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid=[{'penalty': ['l1', 'l2', '15']},
#                          {'C': [1, 10, 100, 1000]}])

# %%
print(grid.best_params_)
grid_predictions = grid.predict(X_test)
# Out:
# {'C': 1000}

# %%
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86     11004
#            1       0.85      0.86      0.86     10925
#
#     accuracy                           0.86     21929
#    macro avg       0.86      0.86      0.86     21929
# weighted avg       0.86      0.86      0.86     21929

# %% [markdown]
# # decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(df_upsampled.drop('target',axis=1),
                                                    df_upsampled['target'], test_size=0.30,
                                                    random_state=None)

# %%
DecisionTreeClassifierModel = DecisionTreeClassifier(criterion='gini',max_depth=5) #criterion can be entropy
DecisionTreeClassifierModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
DT_pred = DecisionTreeClassifierModel.predict(X_test)
DT_accuracy = accuracy_score(y_test, DT_pred)

# %%
print(classification_report(y_test,DT_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87     11025
#            1       0.84      0.93      0.88     10904
#
#     accuracy                           0.88     21929
#    macro avg       0.88      0.88      0.88     21929
# weighted avg       0.88      0.88      0.88     21929

# %%
tree_matrix = confusion_matrix(y_test,DT_pred)
tree_display = ConfusionMatrixDisplay(confusion_matrix = tree_matrix, display_labels = ['NO','YES'])
tree_display.plot()
plt.title("Confusion Matrix of decision tree")
plt.show()

# %% [markdown]
# # Grid

# %%
param={'criterion':['entropy','gini'],
        'max_depth':[3,4,6],
      'random_state':[5,200,100]}

# %%
grid = GridSearchCV(DecisionTreeClassifier(), param, refit = True, verbose = 3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END criterion=entropy, max_depth=3, random_state=5;, score=0.839 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=3, random_state=5;, score=0.839 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=3, random_state=5;, score=0.841 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=3, random_state=5;, score=0.843 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=3, random_state=5;, score=0.839 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=3, random_state=200;, score=0.839 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=3, random_state=200;, score=0.839 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=3, random_state=200;, score=0.841 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=3, random_state=200;, score=0.843 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=3, random_state=200;, score=0.839 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=3, random_state=100;, score=0.839 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=3, random_state=100;, score=0.839 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=3, random_state=100;, score=0.841 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=3, random_state=100;, score=0.843 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=3, random_state=100;, score=0.839 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=4, random_state=5;, score=0.861 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=4, random_state=5;, score=0.863 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=4, random_state=5;, score=0.868 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=4, random_state=5;, score=0.865 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=4, random_state=5;, score=0.863 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=4, random_state=200;, score=0.861 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=4, random_state=200;, score=0.863 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=4, random_state=200;, score=0.868 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=4, random_state=200;, score=0.865 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=4, random_state=200;, score=0.863 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=4, random_state=100;, score=0.861 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=4, random_state=100;, score=0.863 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=4, random_state=100;, score=0.868 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=4, random_state=100;, score=0.865 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=4, random_state=100;, score=0.863 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=6, random_state=5;, score=0.882 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, random_state=5;, score=0.879 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=6, random_state=5;, score=0.889 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, random_state=5;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, random_state=5;, score=0.884 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=6, random_state=200;, score=0.882 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, random_state=200;, score=0.879 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=6, random_state=200;, score=0.890 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, random_state=200;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, random_state=200;, score=0.883 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_depth=6, random_state=100;, score=0.882 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_depth=6, random_state=100;, score=0.879 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_depth=6, random_state=100;, score=0.889 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_depth=6, random_state=100;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_depth=6, random_state=100;, score=0.883 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, random_state=5;, score=0.840 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, random_state=5;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, random_state=5;, score=0.844 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, random_state=5;, score=0.844 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, random_state=5;, score=0.844 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, random_state=200;, score=0.840 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, random_state=200;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, random_state=200;, score=0.844 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, random_state=200;, score=0.844 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, random_state=200;, score=0.844 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=3, random_state=100;, score=0.840 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=3, random_state=100;, score=0.843 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=3, random_state=100;, score=0.844 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=3, random_state=100;, score=0.844 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=3, random_state=100;, score=0.844 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, random_state=5;, score=0.862 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, random_state=5;, score=0.861 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, random_state=5;, score=0.866 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, random_state=5;, score=0.866 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, random_state=5;, score=0.861 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, random_state=200;, score=0.862 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, random_state=200;, score=0.861 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, random_state=200;, score=0.866 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, random_state=200;, score=0.866 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, random_state=200;, score=0.861 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=4, random_state=100;, score=0.862 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=4, random_state=100;, score=0.861 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=4, random_state=100;, score=0.866 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=4, random_state=100;, score=0.866 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=4, random_state=100;, score=0.861 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, random_state=5;, score=0.880 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, random_state=5;, score=0.882 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, random_state=5;, score=0.889 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, random_state=5;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, random_state=5;, score=0.886 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, random_state=200;, score=0.880 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, random_state=200;, score=0.882 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, random_state=200;, score=0.889 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, random_state=200;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, random_state=200;, score=0.886 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=6, random_state=100;, score=0.880 total time=   0.1s
# [CV 2/5] END criterion=gini, max_depth=6, random_state=100;, score=0.882 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=6, random_state=100;, score=0.889 total time=   0.1s
# [CV 4/5] END criterion=gini, max_depth=6, random_state=100;, score=0.884 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=6, random_state=100;, score=0.886 total time=   0.1s
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [3, 4, 6],
#                          'random_state': [5, 200, 100]},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 6, 'random_state': 5}

# %%
grid_predictions = grid.predict(X_test)
print(classification_report(y_test,grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88     18325
#            1       0.86      0.92      0.89     18223
#
#     accuracy                           0.88     36548
#    macro avg       0.89      0.88      0.88     36548
# weighted avg       0.89      0.88      0.88     36548

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
random_model = RandomForestClassifier(n_estimators=500)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_upsampled.drop('target',axis=1),
                                                    df_upsampled['target'], test_size=0.30,
                                                    random_state=None)
random_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
RF_predictions=random_model.predict(X_test)
RF_accuracy = accuracy_score(y_test, RF_predictions)

# %%
RF_accuracy
# Out:
# 0.9647954763099093

# %%
print(classification_report(y_test,RF_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96     11061
#            1       0.93      1.00      0.97     10868
#
#     accuracy                           0.96     21929
#    macro avg       0.97      0.97      0.96     21929
# weighted avg       0.97      0.96      0.96     21929

# %%
random_matrix = confusion_matrix(y_test,RF_predictions)
random_display = ConfusionMatrixDisplay(confusion_matrix = random_matrix, display_labels = ['NO','YES'])
random_display.plot()
plt.title("Confusion Matrix of random forest")
plt.show()

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
X_train, X_test, y_train, y_test = train_test_split(df_upsampled.drop('target',axis=1),
                                                    df_upsampled['target'], test_size=0.30,
                                                    random_state=None)
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
SVC_predictions = model.predict(X_test)
SVC_accuracy = accuracy_score(y_test, SVC_predictions)

# %%
print(classification_report(y_test,SVC_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.85     11026
#            1       0.83      0.86      0.85     10903
#
#     accuracy                           0.85     21929
#    macro avg       0.85      0.85      0.85     21929
# weighted avg       0.85      0.85      0.85     21929

# %%
svc_matrix = confusion_matrix(y_test,SVC_predictions)
svc_display = ConfusionMatrixDisplay(confusion_matrix = svc_matrix, display_labels = ['NO','YES'])
svc_display.plot()
plt.title("Confusion Matrix of support vector machine")
plt.show()

# %% [markdown]
# # Grid

# %%
param = {'C': [0.1,1, 10], 'gamma': [1,0.1,0.01]}

# %%
grid = GridSearchCV(SVC(),param,refit=True,verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END ....................C=0.1, gamma=1;, score=0.509 total time= 4.8min
# [CV 2/5] END ....................C=0.1, gamma=1;, score=0.510 total time= 4.5min
# [CV 3/5] END ....................C=0.1, gamma=1;, score=0.509 total time= 4.2min
# [CV 4/5] END ....................C=0.1, gamma=1;, score=0.507 total time= 4.4min
# [CV 5/5] END ....................C=0.1, gamma=1;, score=0.509 total time= 4.3min
# [CV 1/5] END ..................C=0.1, gamma=0.1;, score=0.602 total time= 2.4min
# [CV 2/5] END ..................C=0.1, gamma=0.1;, score=0.595 total time= 2.4min
# [CV 3/5] END ..................C=0.1, gamma=0.1;, score=0.640 total time= 2.4min
# [CV 4/5] END ..................C=0.1, gamma=0.1;, score=0.606 total time= 2.4min
# [CV 5/5] END ..................C=0.1, gamma=0.1;, score=0.599 total time= 2.3min
# [CV 1/5] END .................C=0.1, gamma=0.01;, score=0.878 total time= 2.5min
# [CV 2/5] END .................C=0.1, gamma=0.01;, score=0.874 total time= 2.8min
# [CV 3/5] END .................C=0.1, gamma=0.01;, score=0.870 total time= 2.9min
# [CV 4/5] END .................C=0.1, gamma=0.01;, score=0.869 total time= 2.5min
# [CV 5/5] END .................C=0.1, gamma=0.01;, score=0.871 total time= 2.4min
# [CV 1/5] END ......................C=1, gamma=1;, score=0.992 total time= 5.7min
# [CV 2/5] END ......................C=1, gamma=1;, score=0.994 total time= 5.4min
# [CV 3/5] END ......................C=1, gamma=1;, score=0.994 total time= 4.8min
# [CV 4/5] END ......................C=1, gamma=1;, score=0.993 total time= 6.3min
# [CV 5/5] END ......................C=1, gamma=1;, score=0.993 total time= 4.9min
# [CV 1/5] END ....................C=1, gamma=0.1;, score=0.991 total time= 4.9min
# [CV 2/5] END ....................C=1, gamma=0.1;, score=0.993 total time= 4.8min
# [CV 3/5] END ....................C=1, gamma=0.1;, score=0.993 total time= 5.0min
# [CV 4/5] END ....................C=1, gamma=0.1;, score=0.991 total time= 4.8min
# [CV 5/5] END ....................C=1, gamma=0.1;, score=0.991 total time= 5.0min
# [CV 1/5] END ...................C=1, gamma=0.01;, score=0.930 total time= 3.1min
# [CV 2/5] END ...................C=1, gamma=0.01;, score=0.926 total time= 3.1min
# [CV 3/5] END ...................C=1, gamma=0.01;, score=0.920 total time= 3.3min
# [CV 4/5] END ...................C=1, gamma=0.01;, score=0.924 total time= 3.2min
# [CV 5/5] END ...................C=1, gamma=0.01;, score=0.924 total time= 3.1min
# [CV 1/5] END .....................C=10, gamma=1;, score=0.992 total time= 6.2min
# [CV 2/5] END .....................C=10, gamma=1;, score=0.994 total time= 6.0min
# [CV 3/5] END .....................C=10, gamma=1;, score=0.994 total time= 6.0min
# [CV 4/5] END .....................C=10, gamma=1;, score=0.993 total time= 6.2min
# [CV 5/5] END .....................C=10, gamma=1;, score=0.993 total time= 6.2min
# [CV 1/5] END ...................C=10, gamma=0.1;, score=0.991 total time= 4.6min
# [CV 2/5] END ...................C=10, gamma=0.1;, score=0.993 total time= 4.5min
# [CV 3/5] END ...................C=10, gamma=0.1;, score=0.993 total time= 4.5min
# [CV 4/5] END ...................C=10, gamma=0.1;, score=0.991 total time= 4.5min
# [CV 5/5] END ...................C=10, gamma=0.1;, score=0.991 total time= 4.6min
# [CV 1/5] END ..................C=10, gamma=0.01;, score=0.955 total time= 5.0min
# [CV 2/5] END ..................C=10, gamma=0.01;, score=0.954 total time= 5.2min
# [CV 3/5] END ..................C=10, gamma=0.01;, score=0.951 total time= 4.6min
# [CV 4/5] END ..................C=10, gamma=0.01;, score=0.952 total time= 4.5min
# [CV 5/5] END ..................C=10, gamma=0.01;, score=0.949 total time= 4.9min
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10], 'gamma': [1, 0.1, 0.01]},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'C': 1, 'gamma': 1}

# %%
grid_predictions = grid.predict(X_test)

# %%
print(classification_report(y_test,grid_predictions))

# %% [markdown]
# # clustring

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
features = ['duration', 'previous', 'poutcome', 'nr.employed', 'pdays']
X = df_upsampled[features]

# %%
# Handle missing values
X.fillna(X.median(), inplace=True)
# Out:
# <ipython-input-162-cb094b235d0c>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df_upsampled['Cluster'] = kmeans.fit_predict(X_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=df_upsampled['Cluster'], cmap='viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-means Clustering')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ## Models Accuracy comparison

# %%
import plotly.express as px

# Assume we have the accuracy scores for each model
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'Gradient Boosting']
accuracy_scores = [LG_accuracy, DT_accuracy, RF_accuracy, SVC_accuracy]

# Create a dictionary of data
data = {'Model': models, 'Accuracy Score': accuracy_scores}

# Create a figure
fig = px.bar(data, x='Model', y='Accuracy Score',title='Comparison of Accuracy Scores for Four Machine Learning Models')

# Set figure size
fig.update_layout(width=600, height=400)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a5c279c2-6871-4fa4-b277-f0e70b1b0bc9" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5c279c2-6871-4fa4-b277-f0e70b1b0bc9")) {                    Plotly.newPlot(                        "a5c279c2-6871-4fa4-b277-f0e70b1b0bc9",                        [{"alignmentgroup":"True","hovertemplate":"Model=%{x}\u003cbr\u003eAccuracy Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Logistic Regression","Decision Tree","Random Forest","Gradient Boosting"],"xaxis":"x","y":[0.8499948698655905,0.8779698116649186,0.9647954763099093,0.8477814765835195],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"soli ...
